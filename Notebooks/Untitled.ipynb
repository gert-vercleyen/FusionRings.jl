# %%
using Revise
using Pkg;
#Pkg.develop(path="/home/gert/Projects/FusionRings.jl/")
#Pkg.develop(path="/Users/gertvercleyen/Projects/FusionRings.jl/")
using FusionRings
using Oscar
using JSON
using Base.Threads

# %%
m=multiplication_table(frl[3])[2,:,:]
# Out:
# 2×2 Matrix{Int64}:
#  0  1
#  1  1

# %%
size(m)
# Out:
# (2, 2)

# %%
j = 13
mt = multiplication_table( frl[ j ] )
mats = [ mt[i,:,:] for i in 1:FusionRings.rank(frl[j])  ]
diagonalize_matrices(mats)
# Out:
# Dummy error for jupyter
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:44
#   [2] show(io::IOContext{IOBuffer}, mi::MIME{Symbol("text/html")}, a::AbstractAlgebra.Generic.MatSpaceElem{QQBarFieldElem})
#     @ AbstractAlgebra ~/.julia/packages/AbstractAlgebra/L8iQ0/src/Matrix.jl:746
#   [3] limitstringmime(mime::MIME{Symbol("text/html")}, x::Any, forcetext::Bool)
#     @ IJulia ~/.julia/packages/IJulia/TXScA/src/inline.jl:56
#   [4] limitstringmime
#     @ ~/.julia/packages/IJulia/TXScA/src/inline.jl:51 [inlined]
#   [5] display_mimestring(m::MIME{Symbol("text/html")}, x::Any)
#     @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:80
#   [6] display_mimestring(mime_array::Vector{MIME}, x::Any)
#     @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:74
#   [7] _display_dict(x::Any)
#     @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:109
#   [8] display_dict(x::Any)
#     @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:133
# ...
